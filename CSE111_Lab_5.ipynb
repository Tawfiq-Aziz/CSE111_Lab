# %%
#Task 1
class Circle:
    def __init__(self,rad):
        self.__rad = rad
    def getRadius(self):
        return self.__rad
    def area(self):
        import math 
        return math.pi*self.__rad**2
    def setRadius(self, rad):
        self.__rad = rad
        return self.__rad
    
c1 = Circle(4)
print("First circle radius:" , c1.getRadius())
print("First circle area:" , c1.area())
c2 = Circle(5)
print("Second circle radius:" , c2.getRadius())
print("Second circle area:" , c2.area())
# Out:
# First circle radius: 4
# First circle area: 50.26548245743669
# Second circle radius: 5
# Second circle area: 78.53981633974483

# %%
#Task 2
class Triangle:
    def __init__(self,base,height):
        self.__base = base 
        self.__height = height 
    def getBase(self):
         return self.__base 
    def getHeight(self):
        return self.__height
    def setBase(self,base):
        self.__base = base 
        return self.__base
    def setHeight(self,height):
        self.__height = height
        return self.__height
    def area(self):
        area = (self.__height*self.__base)/2
        return area
t1 = Triangle(10, 5)
print("First Triangle Base:" , t1.getBase())
print("First Triangle Height:" , t1.getHeight())
print("First Triangle area:" ,t1.area())


t2 = Triangle(5, 3)
print("Second Triangle Base:" , t2.getBase())
print("Second Triangle Height:" , t2.getHeight())
print("Second Triangle area:" ,t2.area())
# Out:
# First Triangle Base: 10
# First Triangle Height: 5
# First Triangle area: 25.0
# Second Triangle Base: 5
# Second Triangle Height: 3
# Second Triangle area: 7.5

# %%
#task 3 
class Teacher:
    def __init__(self,name,dept):
        self.__name = name 
        self.__dept = dept
        self.__cl =[]
    def addCourse(self,obj):
        self.__cl.append(obj.course)
    def printDetail(self):
        print('====================================')
        print(f'Name:{self.__name}')
        print(f'Department:{self.__dept}')
        print('List of courses ')
        print('====================================')
        for i in self.__cl:
            print(i)
class Course:
    def __init__(self,course):
        self.course= course

t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE")                          
c1 = Course("CSE 110 Programming Language I")                           
c2 = Course("CSE 111 Programming Language-II")                           
c3 = Course("CSE 220 Data Structures")                           
c4 = Course("CSE 221 Algorithms")                           
c5 = Course("CCSE 230 Discrete Mathematics")                           
c6 = Course("CSE 310 Object Oriented Programming")                           
c7 = Course("CSE 320 Data Communications")                          
c8 = Course("CSE 340 Computer Architecture") 
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ...
# Name:Saad Abdullah
# Department:CSE
# List of courses
# ...
# CSE 110 Programming Language I
# CSE 111 Programming Language-II
# ...
# Name:Mumit Khan
# Department:CSE
# List of courses
# ...
# CSE 220 Data Structures
# CSE 221 Algorithms
# CCSE 230 Discrete Mathematics
# ...
# Name:Sadia Kazi
# Department:CSE
# List of courses
# ...
# CSE 310 Object Oriented Programming
# CSE 320 Data Communications
# CSE 340 Computer Architecture

# %%
#Task 4
class Team:
    def __init__(self,country=None):
        self.__country = country
        self.__pl = []
    def setName(self,new_c):
        self.__country = new_c
    def addPlayer(self,player_name):
        self.__pl.append(player_name.name)
    def printDetail(self):
        print('=====================')
        print(f'Team:{self.__country}')
        print(f'List of players:\n{self.__pl}')
class Player:
    def __init__(self,name):
        self.name = name 

b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()
# Out:
# ...
# Team:Bangladesh
# List of players:
# ['Mashrafi', 'Tamim']
# ...
# Team:Australia
# List of players:
# ['Ponting', 'Lee']

# %%
#TASK 5
class Student:
    def __init__(self, name, id, department):
        self.name = name
        self.id = id
        self.department = department
        self.email = None
        self.password = None
        self.login_status = None
        print("Student object is created!")
        

class Usis:
    def __init__(self):
      self.courses = ""
      print("USIS is ready to use!")
        
    def login(self, student):
        if student.email is None or student.password is None:
            print("Email and password need to be set.")
        else:
            student.login_status = True
            print("Login successful!")
            
    def advising(self, student, *courses):
        if student.login_status is None:
            print("Please login to advise courses!")
        elif len(courses) == 0:
            print("You haven't selected any courses.")
        elif len(courses) > 3:
            print("You need special approval to take more than 3 courses.")
        else:
            for i in courses:
              self.courses+=str(i)+", "
            print("Advising successful!")
            
    def individualDetails(self, student):
        return f"Name: {student.name}\nID: {student.id}\nDepartment: {student.department}\nAdvised courses: {self.courses}"
rakib = Student("Rakib", 12301455, "CSE")
print("1***********************")
usis_obj = Usis()
print("2***********************")
usis_obj.login(rakib)
print("3***********************")
usis_obj.advising(rakib)
print("4***********************")
rakib.email = "rakib@hotmail.com"
rakib.password = "1234"
print("5***********************")
usis_obj.login(rakib)
print("6***********************")
usis_obj.advising(rakib)
print("7***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110", "CSE260")
print("8***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110")
print("9***********************")
print(usis_obj.individualDetails(rakib))
# Out:
# Student object is created!
# 1***********************
# USIS is ready to use!
# 2***********************
# Email and password need to be set.
# 3***********************
# Please login to advise courses!
# 4***********************
# 5***********************
# Login successful!
# 6***********************
# You haven't selected any courses.
# 7***********************
# You need special approval to take more than 3 courses.
# 8***********************
# Advising successful!
# 9***********************
# Name: Rakib
# ID: 12301455
# Department: CSE
# Advised courses: CSE110, PHY111, MAT110,

# %%
#Task 6
class Train:
  def __init__(self,t_name,*info):
    self.t_name=t_name
    self.info=info
    print(f"Welcome abroad on {self.t_name}\nStart:{self.info[0]}\nDestination:{self.info[-1]}")
    self.p_dict1={}

  def addPassenger(self,*obj):
    for i in obj:
      p_list1=[]
      print(i.p_name,"welcome abroad")
      if i.starting==None:
        i.starting=self.info[0]
      p_list1.append(i.starting)
      if i.finishing==None:
        i.finishing=self.info[-1]
      p_list1.append(i.finishing)
      self.p_dict1.update({i.p_name:p_list1})

  def allPassengerDetails(self):
    for k,v in self.p_dict1.items():
      x=self.info[self.info.index(v[0]):self.info.index(v[1])]
      print(f"Name:{k},Start:{v[0]},Destinatiion:{v[1]},Fair:${len(x)*100}")

class Passenger:
  def __init__(self,p_name,starting=None,finishing=None):
    self.p_name=p_name
    self.starting=starting
    self.finishing=finishing

t1 = Train('T1-Express','New York','Manhattan','Brooklyn','Boston')
print("1========================")
p1 =Passenger("Naruto")
t1.addPassenger(p1)
p2 = Passenger("Sasuke","Manhattan")
p3 = Passenger("Hinata","Manhattan","Brooklyn")
print("2========================")
t1.addPassenger(p2,p3)
print("3========================")
t1.allPassengerDetails()
print("4========================")
t2 = Train('Europe-Express','London','Paris','Brussels','Turkey')
print("5========================")
p4 =Passenger("Max","London","Brussels")
p5 = Passenger("Eleven","Paris")
p6 = Passenger("Mike","Brussels")
t2.addPassenger(p4,p5,p6)
print("6========================")
t2.allPassengerDetails()
# Out:
# Welcome abroad on T1-Express
# Start:New York
# Destination:Boston
# 1========================
# Naruto welcome abroad
# 2========================
# Sasuke welcome abroad
# Hinata welcome abroad
# 3========================
# Name:Naruto,Start:New York,Destinatiion:Boston,Fair:$300
# Name:Sasuke,Start:Manhattan,Destinatiion:Boston,Fair:$200
# Name:Hinata,Start:Manhattan,Destinatiion:Brooklyn,Fair:$100
# 4========================
# Welcome abroad on Europe-Express
# Start:London
# Destination:Turkey
# 5========================
# Max welcome abroad
# Eleven welcome abroad
# Mike welcome abroad
# 6========================
# Name:Max,Start:London,Destinatiion:Brussels,Fair:$200
# Name:Eleven,Start:Paris,Destinatiion:Turkey,Fair:$200
# Name:Mike,Start:Brussels,Destinatiion:Turkey,Fair:$100

# %%
#Task 6
class Passenger:
   def __init__(self, name, start=None, destination=None):
        self.name = name
        self.start = start
        self.destination = destination

class Train:
    def __init__(self, train_name, *destinations):
        self.train_name = train_name
        self.tstart = destinations[0]
        self.destinations = destinations
        self.destinations = destinations[-1]
        self.passengers = []
        
        print(f"Welcome aboard on {self.train_name}")
        print(f"Start: {self.tstart}")
        print(f"Destination: {self.destinations[-1]}")
        
    def addPassenger(self, *passengers):
        for i in passengers:
            self.passengers.append(i)
            print(f"{i.name} welcome aboard")
            if i.start==None:
              i.start= self.tstart
            if i.destination==None:
              i.destination = self.destinations
            
    def allPassengerDetails(self):
      for i in self.passengers:
        #print(f'Name:{i.name} Start:{i.start} Destination:{i.destination}')
        startIDX= self.destinations.find(i.start)
        endDest= self.destinations.find(i.destination)
        fare = (endDest-startIDX)*100
        print(f'Name:{i.name} Start:{i.start} Destination:{i.destination} Fare: $({fare}')



t1 = Train('T1-Express','New York','Manhattan','Brooklyn','Boston')
print("1========================")
p1 =Passenger("Naruto")
t1.addPassenger(p1)
p2 = Passenger("Sasuke","Manhattan")
p3 = Passenger("Hinata","Manhattan","Brooklyn")
print("2========================")
t1.addPassenger(p2,p3)
print("3========================")
t1.allPassengerDetails()
print("4========================")
t2 = Train('Europe-Express','London','Paris','Brussels','Turkey')
print("5========================")
p4 =Passenger("Max","London","Brussels")
p5 = Passenger("Eleven","Paris")
p6 = Passenger("Mike","Brussels")
t2.addPassenger(p4,p5,p6)
print("6========================")
t2.allPassengerDetails()
# Out:
# Welcome aboard on T1-Express
# Start: New York
# Destination: n
# 1========================
# Naruto welcome aboard
# 2========================
# Sasuke welcome aboard
# Hinata welcome aboard
# 3========================
# Name:Naruto Start:New York Destination:Boston Fare: $(100
# Name:Sasuke Start:Manhattan Destination:Boston Fare: $(100
# Name:Hinata Start:Manhattan Destination:Brooklyn Fare: $(0
# 4========================
# Welcome aboard on Europe-Express
# Start: London
# Destination: y
# 5========================
# Max welcome aboard
# Eleven welcome aboard
# Mike welcome aboard
# 6========================
# Name:Max Start:London Destination:Brussels Fare: $(0
# Name:Eleven Start:Paris Destination:Turkey Fare: $(100
# Name:Mike Start:Brussels Destination:Turkey Fare: $(100

# %%
#7
class BracuStudent:
  def __init__(self,n,l):
    self.name=n
    self.home=l
    self.pas=False
  def show_details(self):
    print(f'Student Name:{self.name}\nLives in {self.home}\nHave Bus Pass? {self.pas}')
  def get_pass(self):
    self.pas=True
    
class  BracuBus:
  def __init__(self,r,c=2):
    self.route=r
    self.capacity=c
    self.c=0
    self.lst=[]
  def board(self,*args):
    if len(args)==0:
      print("No passenger!")
    for i in args:
      if i.pas==True:
        if i.home==self.route:
          if self.c==self.capacity:
            print("Bus is full!")
          else:
            self.lst.append(i.name)
            print(f"{i.name} boarded the bus")
            self.c+=1
        if i.home!=self.route:
          print("You got on wrong bus!")
      elif i.pas==False:
        print("You don't have bus pass!")
  def show_details(self):
    print(f'Bus Route:{self.route}\nPassengers Count: {self.c} (Max: {self.capacity})\nPassengers On Board:{self.lst}') 
st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1, st2)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2, st3)
print("10===========================")
bus1.show_details()
# Out:
# 1===========================
# Student Name:Afif
# Lives in Mirpur
# Have Bus Pass? False
# Student Name:Shanto
# Lives in Motijheel
# Have Bus Pass? False
# 2===========================
# Student Name:Taskin
# Lives in Mirpur
# Have Bus Pass? False
# 3===========================
# Bus Route:Mirpur
# Passengers Count: 0 (Max: 2)
# Passengers On Board:[]
# Bus Route:Azimpur
# Passengers Count: 0 (Max: 5)
# Passengers On Board:[]
# 4===========================
# 5===========================
# Student Name:Shanto
# Lives in Motijheel
# Have Bus Pass? True
# Student Name:Taskin
# Lives in Mirpur
# Have Bus Pass? True
# 6===========================
# No passenger!
# 7===========================
# You don't have bus pass!
# You got on wrong bus!
# 8===========================
# Student Name:Afif
# Lives in Mirpur
# Have Bus Pass? True
# Student Name:Shanto
# Lives in Mirpur
# Have Bus Pass? True
# 9===========================
# Afif boarded the bus
# Shanto boarded the bus
# Bus is full!
# ...

# %%
#task 8 
class Library:
  def __init__(self,ln,ld):
    self.libraryname=ln
    self.librarydict=ld
  def details(self):
    print(f"Books availability:\n{self.librarydict}")
class Reader:
  def __init__(self,rn):
    self.readername=rn
    self.borrowedbook={}
    self.sum=0
  def borrow(self,l,*args):
    self.librarylocation=l
    self.args=args
    for k,v in l.librarydict.items():
      for i in args:
        if i==k:
          if v > 0:
            self.sum=0
            for k,v in self.borrowedbook.items():
              self.sum+=v
            if self.sum<=5:
               v-=1
               if i in self.borrowedbook:
                 self.borrowedbook[i]+=1
               else:
                 self.borrowedbook[i]=1
               print(f"{i} book is borrowed successfully.")
            else:
              print("You cannot borrow more than 5 books.")
          else:
            print(f"{i} books are not available at the moment.")
  def readerInfo(self,g=None):
    if g==None:
      print(f'{self.readername} you have {self.sum+1} book(s) with you.')
      for k,v in self.borrowedbook.items():
        print(f'Books on {k}: {v}')
    else:
      for k,v in self.borrowedbook.items():
        if g==k:
          print(f'{self.readername}, you have {v} {g} book(s) with you.')

    
L1=Library('Dhaka',{'Arts':15,'Fiction':135,'Politics':2,'Science':11,'Poetry':15})
L1.details()
print("1----------------------")
r1=Reader('Aladdin')
r1.borrow(L1,'Arts','Fiction','Fiction','Politics')
print("2----------------------")
r1.borrow(L1,'Politics','Fiction')
print("3----------------------")
r1.readerInfo()
print("4----------------------")
r1.readerInfo('Fiction')
print("5----------------------")
L1.details()
print("6----------------------")
r2=Reader('Jasmine')
r2.borrow(L1,'Politics','Poetry')
print("7----------------------")
r2.readerInfo()
print("8----------------------")
L1.details()
# Out:
# Books availability:
# {'Arts': 15, 'Fiction': 135, 'Politics': 2, 'Science': 11, 'Poetry': 15}
# 1----------------------
# Arts book is borrowed successfully.
# Fiction book is borrowed successfully.
# Politics book is borrowed successfully.
# 2----------------------
# Fiction book is borrowed successfully.
# Politics book is borrowed successfully.
# 3----------------------
# Aladdin you have 5 book(s) with you.
# Books on Arts: 1
# Books on Fiction: 2
# Books on Politics: 2
# 4----------------------
# Aladdin, you have 2 Fiction book(s) with you.
# 5----------------------
# Books availability:
# {'Arts': 15, 'Fiction': 135, 'Politics': 2, 'Science': 11, 'Poetry': 15}
# 6----------------------
# Politics book is borrowed successfully.
# Poetry book is borrowed successfully.
# 7----------------------
# Jasmine you have 2 book(s) with you.
# Books on Politics: 1
# Books on Poetry: 1
# 8----------------------
# Books availability:
# ...
