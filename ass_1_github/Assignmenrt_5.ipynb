# %%
#Task 1
class Circle:
    def __init__(self,rad):
        self.__rad = rad
    def getRadius(self):
        return self.__rad
    def area(self):
        import math 
        return math.pi*self.__rad**2
    def setRadius(self, rad):
        self.__rad = rad
        return self.__rad
    
c1 = Circle(4)
print("First circle radius:" , c1.getRadius())
print("First circle area:" , c1.area())
c2 = Circle(5)
print("Second circle radius:" , c2.getRadius())
print("Second circle area:" , c2.area())
# Out:
# First circle radius: 4
# First circle area: 50.26548245743669
# Second circle radius: 5
# Second circle area: 78.53981633974483

# %%
#Task 2
class Triangle:
    def __init__(self,base,height):
        self.__base = base 
        self.__height = height 
    def getBase(self):
         return self.__base 
    def getHeight(self):
        return self.__height
    def setBase(self,base):
        self.__base = base 
        return self.__base
    def setHeight(self,height):
        self.__height = height
        return self.__height
    def area(self):
        area = (self.__height*self.__base)/2
        return area
t1 = Triangle(10, 5)
print("First Triangle Base:" , t1.getBase())
print("First Triangle Height:" , t1.getHeight())
print("First Triangle area:" ,t1.area())


t2 = Triangle(5, 3)
print("Second Triangle Base:" , t2.getBase())
print("Second Triangle Height:" , t2.getHeight())
print("Second Triangle area:" ,t2.area())
# Out:
# First Triangle Base: 10
# First Triangle Height: 5
# First Triangle area: 25.0
# Second Triangle Base: 5
# Second Triangle Height: 3
# Second Triangle area: 7.5

# %%
#task 3 
class Teacher:
    def __init__(self,name,dept):
        self.__name = name 
        self.__dept = dept
        self.cl =[]
    def addCourse(self,obj):
        self.cl.append(obj.course)
    def printDetail(self):
        print('====================================')
        print(f'Name:{self.__name}')
        print(f'Department:{self.__dept}')
        print('List of courses ')
        print('====================================')
        for i in self.cl:
            print(i)
class Course:
    def __init__(self,course):
        self.course= course

t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE")                          
c1 = Course("CSE 110 Programming Language I")                           
c2 = Course("CSE 111 Programming Language-II")                           
c3 = Course("CSE 220 Data Structures")                           
c4 = Course("CSE 221 Algorithms")                           
c5 = Course("CCSE 230 Discrete Mathematics")                           
c6 = Course("CSE 310 Object Oriented Programming")                           
c7 = Course("CSE 320 Data Communications")                          
c8 = Course("CSE 340 Computer Architecture") 
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ====================================
# Name:Saad Abdullah
# Department:CSE
# List of courses
# ====================================
# CSE 110 Programming Language I
# CSE 111 Programming Language-II
# ====================================
# Name:Mumit Khan
# Department:CSE
# List of courses
# ====================================
# CSE 220 Data Structures
# CSE 221 Algorithms
# CCSE 230 Discrete Mathematics
# ====================================
# Name:Sadia Kazi
# Department:CSE
# List of courses
# ====================================
# CSE 310 Object Oriented Programming
# CSE 320 Data Communications
# CSE 340 Computer Architecture

# %%
#Task 4
class Team:
    def __init__(self,country=None):
        self.__country = country
        self.__pl = []
    def setName(self,new_c):
        self.__country = new_c
    def addPlayer(self,player_name):
        self.__pl.append(player_name.name)
    def printDetail(self):
        print('=====================')
        print(f'Team:{self.__country}')
        print(f'List of players:\n{self.__pl}')
class Player:
    def __init__(self,name):
        self.name = name 

b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()
# Out:
# =====================
# Team:Bangladesh
# List of players:
# ['Mashrafi', 'Tamim']
# =====================
# Team:Australia
# List of players:
# ['Ponting', 'Lee']

# %%
#Task 5 
class Student:
    def __init__(self,name,id,dept):
        self.__name = name 
        self.__id = id
        self.__dept = dept
        print()

# %%
#Task 6
class Passenger:
    def __init__(self,name,start,pass_destination):
        self.name = name 
        self.start = start 
        self.pass_destination = pass_destination
    def addPassenger(self,*args):
        self.args = args
        if len(self.args) >=1:
            pass
        elif len(self.args)==2:
            self.args+= self.args
        elif len(self.args) >= 3:
                self.args+= self.args
    def allPassengerDetail(self):
         print(f'welcome aboard on {self.t_name}')
         print(f'start:{self.start}')
         print(f'Destination:{self.destination}')
         print(f'{self.name} welcome aboard')
         print(f'Name:{self.name} start:{self.start} Destination{self.pass_destination}')



class Train:
    def __init__(self,t_name,start,*destination):
        self.t_name = t_name
        self.start = start 
        self.destination = destination[-1]

t1 = Train('T1-Express','New York','Manhattan','Brooklyn','Boston')
print("1========================")
p1 =Passenger("Naruto")
t1.addPassenger(p1)
p2 = Passenger("Sasuke","Manhattan")
p3 = Passenger("Hinata","Manhattan","Brooklyn")
print("2========================")
t1.addPassenger(p2,p3)
print("3========================")
t1.allPassengerDetails()
print("4========================")
t2 = Train('Europe-Express','London','Paris','Brussels','Turkey')
print("5========================")
p4 =Passenger("Max","London","Brussels")
p5 = Passenger("Eleven","Paris")
p6 = Passenger("Mike","Brussels")
t2.addPassenger(p4,p5,p6)
print("6========================")
t2.allPassengerDetails()
# Out:
# 1========================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14832\586896967.py in <module>
#      30 t1 = Train('T1-Express','New York','Manhattan','Brooklyn','Boston')
#      31 print("1========================")
# ---> 32 p1 =Passenger("Naruto")
#      33 t1.addPassenger(p1)
#      34 p2 = Passenger("Sasuke","Manhattan")
#
# TypeError: __init__() missing 2 required positional arguments: 'start' and 'pass_destination'

# %%
def __add__(self):
                 self.args[0] + self.args[1]

# %%
class Train:
  def __init__(self,name,*args):
    self.express=name
    self.args=args
    self.d={}
    print(f'Welcome aboard on {self.express}\nStart:{self.args[0]}\nDestination:{self.args[len(self.args)-1]}')
  def addPassenger(self,*argss):
    for i in argss:
      print(f'{i.name} welcome aboard')
      ls=[]
      f=0
      t=0
      w=0
      if i.fr==None:
        ls.append(self.args[0])
        ls.append(self.args[len(self.args)-1])
        ls.append((len(self.args)-1)*100)
        self.d[i.name]=ls
      elif i.to==None:
        for j in range(len(self.args)):
          if i.fr==self.args[j]:
            f=j+1
        ls.append(self.args[0])
        ls.append(i.fr)
        w= len(self.args)-f
        ls.append(w*100)
        self.d[i.name]=ls
      else:
        for j in range(len(self.args)):
          if i.fr==self.args[j]:
            f=j+1
          elif i.to==self.args[j]:
            t=j+1
        w=t-f
        ls.append(i.fr)
        ls.append(i.to)
        ls.append(w*100)
        self.d[i.name]=ls
  def allPassengerDetails(self):
    for k,v in self.d.items():
      print(f'Name: {k},Start:{v[0]}, Destination: {v[1]}, Fair{v[len(v)-1]}')
class Passenger:
  def __init__(self,name,fr=None,to=None):
    self.name=name
    self.fr=fr
    self.to=to

t1 = Train('T1-Express','New York','Manhattan','Brooklyn','Boston')
print("1========================")
p1 =Passenger("Naruto")
t1.addPassenger(p1)
p2 = Passenger("Sasuke","Manhattan")
p3 = Passenger("Hinata","Manhattan","Brooklyn")
print("2========================")
t1.addPassenger(p2,p3)
print("3========================")
t1.allPassengerDetails()
print("4========================")
t2 = Train('Europe-Express','London','Paris','Brussels','Turkey')
print("5========================")
p4 =Passenger("Max","London","Brussels")
p5 = Passenger("Eleven","Paris")
p6 = Passenger("Mike","Brussels")
t2.addPassenger(p4,p5,p6)
print("6========================")
t2.allPassengerDetails()
# Out:
# Welcome aboard on T1-Express
# Start:New York
# Destination:Boston
# 1========================
# Naruto welcome aboard
# 2========================
# Sasuke welcome aboard
# Hinata welcome aboard
# 3========================
# Name: Naruto,Start:New York, Destination: Boston, Fair300
# Name: Sasuke,Start:New York, Destination: Manhattan, Fair200
# Name: Hinata,Start:Manhattan, Destination: Brooklyn, Fair100
# 4========================
# Welcome aboard on Europe-Express
# Start:London
# Destination:Turkey
# 5========================
# Max welcome aboard
# Eleven welcome aboard
# Mike welcome aboard
# 6========================
# Name: Max,Start:London, Destination: Brussels, Fair200
# Name: Eleven,Start:London, Destination: Paris, Fair200
# Name: Mike,Start:London, Destination: Brussels, Fair100
